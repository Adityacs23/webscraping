# %% [markdown]
# <a href="https://colab.research.google.com/github/Adityacs23/webscraping/blob/main/CA2_DATASCIENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **import data into a program**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
from statsmodels import api
from scipy import stats as st
from scipy import stats 
from scipy.optimize import minimize
import statsmodels.api as sm

# %%
path="/content/pseudo_facebook.csv"

# %% [markdown]
# **display first and last 5 rows in data set (head & tail)**

# %%
data= pd.read_csv(path)

result = data.head(5)
print("First 5 rows of the Data set:")
print(result)
# Out:
# First 5 rows of the Data set:
#     userid  age  dob_day  ...  mobile_likes_received  www_likes www_likes_received
# 0  2094382   14       19  ...                      0          0                  0
# 1  1192601   14        2  ...                      0          0                  0
# 2  2083884   14       16  ...                      0          0                  0
# 3  1203168   14       25  ...                      0          0                  0
# 4  1733186   14        4  ...                      0          0                  0
#
# [5 rows x 15 columns]

# %%
result = data.tail(5)
print("last 5 rows of the Data set:")
print(result)
# Out:
# last 5 rows of the Data set:
#         userid  age  ...  www_likes  www_likes_received
# 62372  1721671   21  ...          0                   0
# 62373  1916866   21  ...          0                   0
# 62374  1497580   23  ...          0                   0
# 62375  1075236   23  ...          0                   0
# 62376  1001624   23  ...          0                   0
#
# [5 rows x 15 columns]

# %% [markdown]
# **shape of data set**

# %%
print(data.shape,"Shape of dataset")
# Out:
# (62377, 15) Shape of dataset

# %% [markdown]
# **cloumns of data set**

# %%
print(data.columns)

# %% [markdown]
# **number of unique values**

# %%
data.nunique()
# Out:
# userid                   62377
# age                        101
# dob_day                     31
# dob_year                   101
# dob_month                   12
# gender                       2
# tenure                    2245
# friend_count               135
# friendships_initiated      130
# likes                     1455
# likes_received             925
# mobile_likes              1202
# mobile_likes_received      634
# www_likes                  873
# www_likes_received         618
# dtype: int64

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(20,12))
plt.subplot(1,2,1)
plt.title("Fraud transactions 'Y' wrt Education ",fontsize=20)
sns.countplot('insured_education_level',data=df)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,12))
plt.subplot(1,2,2)
plt.title("Fraud transactions 'Y' wrt Occupation",fontsize=20)
sns.countplot('insured_occupation',data=df)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(16,6))
plt.title("fraud transactionn 'Y' wrt Hobbies",fontsize=20)
sns.countplot('insured_hobbies',data=df)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,8))
plt.title("fraud transactions wrt Gender",fontsize=20)
sns.barplot(x='insured_sex',y='total_claim_amount',hue='fraud_reported',data=data)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot('auto_make',data=df)
plt.title("Count of Auto make which have Fraud claim",fontsize=20)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
